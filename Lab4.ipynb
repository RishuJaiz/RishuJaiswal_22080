# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#loading the dataset
df = pd.read_csv("C:\\Users\\Rishu Jaiswal\\Downloads\\archive (2)\\Data\\features_30_sec.csv")

# %%
df.shape
# Out:
# (1000, 60)

# %%
df.head()
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# ...

# %%
#finding number of classes
np.unique(df['label'])
# Out:
# array(['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz',
#        'metal', 'pop', 'reggae', 'rock'], dtype=object)

# %%
#dataframe for blues class
blues_class_df = df[df['label']=='blues']

blues_class_df
# Out:
#            filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0   blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1   blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2   blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3   blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4   blues.00004.wav  661794          0.308526         0.087841  0.091529
# ..              ...     ...               ...              ...       ...
# 95  blues.00095.wav  661794          0.369944         0.091291  0.187093
# 96  blues.00096.wav  661794          0.260525         0.091813  0.051400
# 97  blues.00097.wav  661794          0.375062         0.093856  0.198329
# 98  blues.00098.wav  661794          0.442966         0.078316  0.125455
# 99  blues.00099.wav  661794          0.370215         0.085141  0.105011
#
#      rms_var  spectral_centroid_mean  spectral_centroid_var  \
# ...

# %%
#mean(class centroid) for blues class
blues_class_mean = np.mean(blues_class_df.iloc[:,1:-1], axis=0)
blues_class_mean
# Out:
# length                     6.617940e+05
# chroma_stft_mean           3.414288e-01
# chroma_stft_var            9.070045e-02
# rms_mean                   1.360671e-01
# rms_var                    3.014592e-03
# spectral_centroid_mean     1.727585e+03
# spectral_centroid_var      2.897389e+05
# spectral_bandwidth_mean    1.931447e+03
# spectral_bandwidth_var     1.136327e+05
# rolloff_mean               3.636877e+03
# rolloff_var                1.505459e+06
# zero_crossing_rate_mean    7.896919e-02
# zero_crossing_rate_var     1.634280e-03
# harmony_mean              -4.581761e-04
# harmony_var                1.355381e-02
# perceptr_mean             -5.644669e-04
# perceptr_var               4.624092e-03
# tempo                      1.207422e+02
# mfcc1_mean                -1.645943e+02
# mfcc1_var                  3.659267e+03
# mfcc2_mean                 1.139399e+02
# mfcc2_var                  6.191898e+02
# mfcc3_mean                -7.386837e+00
# ...

# %%
#Spread(standard deviation) for blues class
blues_class_std = np.std(blues_class_df.iloc[:,1:-1], axis = 0)
blues_class_std
# Out:
# length                     0.000000e+00
# chroma_stft_mean           5.812888e-02
# chroma_stft_var            6.608321e-03
# rms_mean                   5.171720e-02
# rms_var                    1.883872e-03
# spectral_centroid_mean     5.129420e+02
# spectral_centroid_var      1.759409e+05
# spectral_bandwidth_mean    3.285591e+02
# spectral_bandwidth_var     7.653573e+04
# rolloff_mean               1.154834e+03
# rolloff_var                1.180694e+06
# zero_crossing_rate_mean    3.503644e-02
# zero_crossing_rate_var     9.741404e-04
# harmony_mean               1.469016e-03
# harmony_var                9.064366e-03
# perceptr_mean              1.421367e-03
# perceptr_var               4.475158e-03
# tempo                      3.163236e+01
# mfcc1_mean                 8.420772e+01
# mfcc1_var                  2.263842e+03
# mfcc2_mean                 1.980763e+01
# mfcc2_var                  4.247318e+02
# mfcc3_mean                 1.917316e+01
# ...

# %%
#dataframe for classical class
classical_class_df = df[df['label']=='classical']

# %%
#mean(centroid) for classical class
classical_class_mean = np.mean(classical_class_df.iloc[:,1:-1], axis=0)
classical_class_mean
# Out:
# length                     662116.100000
# chroma_stft_mean                0.263542
# chroma_stft_var                 0.085117
# rms_mean                        0.042920
# rms_var                         0.000706
# spectral_centroid_mean       1353.878837
# spectral_centroid_var      123433.708255
# spectral_bandwidth_mean      1521.709862
# spectral_bandwidth_var      82450.128596
# rolloff_mean                 2482.325982
# rolloff_var                607886.734665
# zero_crossing_rate_mean         0.077611
# zero_crossing_rate_var          0.000824
# harmony_mean                   -0.000246
# harmony_var                     0.003074
# perceptr_mean                  -0.000182
# perceptr_var                    0.000209
# tempo                         127.920952
# mfcc1_mean                   -320.051968
# mfcc1_var                    5280.625733
# mfcc2_mean                    141.267681
# mfcc2_var                     717.406603
# mfcc3_mean                    -19.677586
# ...

# %%
#spread(standard deviation) for classical class
classical_class_std = np.std(classical_class_df.iloc[:,1:-1], axis=0)
classical_class_std
# Out:
# length                       1575.710059
# chroma_stft_mean                0.043875
# chroma_stft_var                 0.003176
# rms_mean                        0.036645
# rms_var                         0.000847
# spectral_centroid_mean        346.419073
# spectral_centroid_var      100859.728207
# spectral_bandwidth_mean       252.961663
# spectral_bandwidth_var      76745.911734
# rolloff_mean                  747.249526
# rolloff_var                614692.578790
# zero_crossing_rate_mean         0.025904
# zero_crossing_rate_var          0.000681
# harmony_mean                    0.000605
# harmony_var                     0.005515
# perceptr_mean                   0.000405
# perceptr_var                    0.000454
# tempo                          33.530689
# mfcc1_mean                    100.891385
# mfcc1_var                    3783.304909
# mfcc2_mean                     23.671831
# mfcc2_var                     477.436606
# mfcc3_mean                     20.579971
# ...

# %%
#distance between mean vectors between class blues and class classical
np.linalg.norm(blues_class_mean - classical_class_mean)
# Out:
# 913383.4723685097
